# %% [markdown]
# **Importing Libraries**

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **1.Loading Data**

# %%
data_2021_2022 = pd.read_json("my_spotify_data/spotify_extended_streaming_history/Streaming_History_Audio_2021-2022_0.json")
data_2021_2022.head()
# Out:
#                      ts                   username  \
# 0  2021-09-04T10:12:23Z  in4aauxz1myx52i4u2ongssse
# 1  2021-09-04T10:16:20Z  in4aauxz1myx52i4u2ongssse
# 2  2021-09-04T10:17:08Z  in4aauxz1myx52i4u2ongssse
# 3  2021-09-04T10:19:41Z  in4aauxz1myx52i4u2ongssse
# 4  2021-09-04T10:22:57Z  in4aauxz1myx52i4u2ongssse
#
#                              platform  ms_played conn_country  \
# 0  Windows 10 (10.0.22000; x64; AppX)       7130           LK
# 1  Windows 10 (10.0.22000; x64; AppX)     237714           LK
# 2  Windows 10 (10.0.22000; x64; AppX)      47045           LK
# 3  Windows 10 (10.0.22000; x64; AppX)      32500           LK
# 4  Windows 10 (10.0.22000; x64; AppX)     197298           LK
#
#   ip_addr_decrypted user_agent_decrypted  \
# 0   112.134.179.253              unknown
# 1     123.231.86.62              unknown
# 2     123.231.86.62              unknown
# 3     123.231.86.62              unknown
# 4     123.231.86.62              unknown
#
# ...

# %%
data_2022_2023 = pd.read_json("my_spotify_data/spotify_extended_streaming_history/Streaming_History_Audio_2022-2023_1.json")
data_2022_2023.head()
# Out:
#                      ts                   username                 platform  \
# 0  2022-03-24T10:50:16Z  in4aauxz1myx52i4u2ongssse  iOS 15.3.1 (iPhone14,2)
# 1  2022-03-24T10:53:20Z  in4aauxz1myx52i4u2ongssse  iOS 15.3.1 (iPhone14,2)
# 2  2022-03-24T10:58:11Z  in4aauxz1myx52i4u2ongssse  iOS 15.3.1 (iPhone14,2)
# 3  2022-03-24T11:02:48Z  in4aauxz1myx52i4u2ongssse  iOS 15.3.1 (iPhone14,2)
# 4  2022-03-24T11:06:55Z  in4aauxz1myx52i4u2ongssse  iOS 15.3.1 (iPhone14,2)
#
#    ms_played conn_country ip_addr_decrypted user_agent_decrypted  \
# 0     144090           LK   175.157.235.200              unknown
# 1     184732           LK   175.157.235.200              unknown
# 2     289334           LK   175.157.235.200              unknown
# 3     275986           LK   175.157.235.200              unknown
# 4     247066           LK   175.157.235.200              unknown
#
#   master_metadata_track_name master_metadata_album_artist_name  \
# ...

# %%
data_2023_2024 = pd.read_json("my_spotify_data/spotify_extended_streaming_history/Streaming_History_Audio_2023-2024_2.json")
data_2023_2024.head()
# Out:
#                      ts                   username platform  ms_played  \
# 0  2023-04-03T20:23:29Z  in4aauxz1myx52i4u2ongssse      ios     153818
# 1  2023-04-03T20:28:00Z  in4aauxz1myx52i4u2ongssse      ios     227626
# 2  2023-04-03T20:30:20Z  in4aauxz1myx52i4u2ongssse      ios     112853
# 3  2023-04-03T20:33:13Z  in4aauxz1myx52i4u2ongssse      ios      15466
# 4  2023-04-03T20:44:40Z  in4aauxz1myx52i4u2ongssse      ios      12040
#
#   conn_country ip_addr_decrypted user_agent_decrypted  \
# 0           LK   175.157.197.246              unknown
# 1           LK   175.157.197.246              unknown
# 2           LK   175.157.197.246              unknown
# 3           LK   175.157.197.246              unknown
# 4           LK   175.157.197.246              unknown
#
#                        master_metadata_track_name  \
# 0                 Shoba - Garden Acoustic Version
# 1    No Complaints (feat. Offset & Drake) (Bonus)
# 2                                    Denied in UK
# ...

# %% [markdown]
# **2.Start of Cleaning Process**
#
# Merging Datasets

# %%
merged_dataset = pd.concat([data_2021_2022, data_2022_2023, data_2023_2024], ignore_index=True)
merged_dataset.head()
# Out:
#                      ts                   username  \
# 0  2021-09-04T10:12:23Z  in4aauxz1myx52i4u2ongssse
# 1  2021-09-04T10:16:20Z  in4aauxz1myx52i4u2ongssse
# 2  2021-09-04T10:17:08Z  in4aauxz1myx52i4u2ongssse
# 3  2021-09-04T10:19:41Z  in4aauxz1myx52i4u2ongssse
# 4  2021-09-04T10:22:57Z  in4aauxz1myx52i4u2ongssse
#
#                              platform  ms_played conn_country  \
# 0  Windows 10 (10.0.22000; x64; AppX)       7130           LK
# 1  Windows 10 (10.0.22000; x64; AppX)     237714           LK
# 2  Windows 10 (10.0.22000; x64; AppX)      47045           LK
# 3  Windows 10 (10.0.22000; x64; AppX)      32500           LK
# 4  Windows 10 (10.0.22000; x64; AppX)     197298           LK
#
#   ip_addr_decrypted user_agent_decrypted  \
# 0   112.134.179.253              unknown
# 1     123.231.86.62              unknown
# 2     123.231.86.62              unknown
# 3     123.231.86.62              unknown
# 4     123.231.86.62              unknown
#
# ...

# %% [markdown]
# Checking For Missing Values

# %%
missing_values = merged_dataset.isnull().sum()
print("Missing Values:\n", missing_values)
# Out:
# Missing Values:
#  ts                                       0
# username                                 0
# platform                                 0
# ms_played                                0
# conn_country                             0
# ip_addr_decrypted                        0
# user_agent_decrypted                   160
# master_metadata_track_name               0
# master_metadata_album_artist_name        0
# master_metadata_album_album_name         0
# spotify_track_uri                        0
# episode_name                         39815
# episode_show_name                    39815
# spotify_episode_uri                  39815
# reason_start                             0
# reason_end                               0
# shuffle                                  0
# skipped                              26173
# offline                                  0
# offline_timestamp                        0
# incognito_mode                           0
# dtype: int64

# %% [markdown]
# Dropping Columns With Missing Values and Sensitive Info

# %%
# Drop specific columns from merged_dataset
clean_data = merged_dataset.drop(["episode_name", "episode_show_name", "spotify_episode_uri", "user_agent_decrypted", "skipped", "ip_addr_decrypted", "username"], axis=1)

# Display the modified DataFrame
clean_data.head()
# Out:
#                      ts                            platform  ms_played  \
# 0  2021-09-04T10:12:23Z  Windows 10 (10.0.22000; x64; AppX)       7130
# 1  2021-09-04T10:16:20Z  Windows 10 (10.0.22000; x64; AppX)     237714
# 2  2021-09-04T10:17:08Z  Windows 10 (10.0.22000; x64; AppX)      47045
# 3  2021-09-04T10:19:41Z  Windows 10 (10.0.22000; x64; AppX)      32500
# 4  2021-09-04T10:22:57Z  Windows 10 (10.0.22000; x64; AppX)     197298
#
#   conn_country                         master_metadata_track_name  \
# 0           LK                                  Broke In A Minute
# 1           LK                                            Bonnona
# 2           LK  Broken People (Originally Performed by Logic &...
# 3           LK                                             ブルーバード
# 4           LK                            The Bones - with Hozier
#
#   master_metadata_album_artist_name  \
# 0                        Tory Lanez
# 1                            DJ JNK
# ...
